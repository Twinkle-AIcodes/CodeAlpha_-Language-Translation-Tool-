# %% [markdown]
# <a href="https://colab.research.google.com/github/Twinkle-AIcodes/CodeAlpha_-Language-Translation-Tool-/blob/main/Language_Translation_Tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.7 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=28629d2ea0a2fc1355492147637b5400e4bce771616d2f281e52c92e1e30f44c
#   Stored in directory: /root/.cache/pip/wheels/95/0f/04/b17a72024b56a60e499ce1a6313d283ed5ba332407155bee03
# Successfully built googletrans
# ...
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 6.1.0
# ...

# %%
from googletrans import Translator
import ipywidgets as widgets
from IPython.display import display

# %%
translator=Translator()

# %%
def translate_text(text, target_lang ):
  translated = translator.translate(
    text,
    src=source_dropdown.value,
    dest=lang_dropdown.value
)
  return translated.text

# %%
text_input = widgets.Textarea(
    placeholder="Enter text to translate...",
    layout=widgets.Layout(width="100%",height="100px")
)

# %%
source_dropdown = widgets.Dropdown(
    options=[
        ("English","en"),
        ("Hindi","hi"),
        ("French","fr"),
        ("German","de"),
        ("Spanish","es")
    ],
    description="Source:"
)

# %%
translate_button = widgets.Button(description="Translate")
output_box = widgets.Output()

# %%
def on_translate_clicked(b):
  output_box.clear_output()
  translated_text = translate_text(text_input.value, lang_dropdown.value)
  with output_box:
    print("Translated:",translated_text)

# %%
translate_button.on_click(on_translate_clicked)

# %%
display(text_input, lang_dropdown, translate_button, output_box)
# Out:
# Textarea(value='', layout=Layout(height='100px', width='100%'), placeholder='Enter text to translate...')
# Dropdown(description='Source:', options=(('English', 'en'), ('Hindi', 'hi'), ('French', 'fr'), ('German', 'de'…
# Button(description='Translate', style=ButtonStyle())
# Output()
